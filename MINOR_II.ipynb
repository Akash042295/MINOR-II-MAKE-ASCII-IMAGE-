# %% [markdown]
# <a href="https://colab.research.google.com/github/Akash042295/MINOR-II-MAKE-ASCII-IMAGE-/blob/main/MINOR_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #JAMES CAMERON ASCII ART

# %%
def JamesCameron_ascii_art():
    height = 29
    width = 55
    for row in range(height):
        line = ""
        for column in range(width):
            char = " "

            if row == 0:
                if column == 17: char = "."
                elif column == 18: char = "#"
                elif 19 <= column <= 22: char = "-"
                elif 23 <= column <= 24: char = "#"
                elif column == 25: char = "-"
                elif 26 <= column <= 28: char = "#"
                elif column == 29: char = "-"
                elif column == 30: char = "."
                elif column == 31: char = "-"
                elif column == 32: char = "."
                elif column == 33: char = "."

            elif row == 1:

                if column == 14: char = "."
                elif column == 15: char = "-"
                elif column == 16: char = "."
                elif column == 17: char = "-"
                elif column == 18: char = "."
                elif column == 19: char = "-"
                elif column == 20: char = "."
                elif column == 21: char = "-"
                elif column == 22: char = "."
                elif column == 23: char = "#"
                elif column == 24: char = "@"
                elif column == 25: char = "#"
                elif column == 26: char = "."
                elif column == 27: char = "-"
                elif 28 <= column <= 29: char = "#"
                elif column == 30: char = "-"
                elif column == 31: char = "#"
                elif column == 32: char = "-"
                elif column == 33: char = "."
                elif column == 34: char = "-"
                elif column == 35: char = "."

            elif row == 2:
                if 12 <= column <= 13: char = "-"
                elif column == 14: char = "."
                elif column == 15: char = "-"
                elif column == 16: char = "."
                elif column == 17: char = "-"
                elif column == 18: char = "."
                elif 19 <= column <= 20: char = "-"
                elif column == 21: char = "#"
                elif column == 22: char = "."
                elif column == 24: char = "."
                elif column == 25: char = "#"
                elif 26 <= column <= 27: char = "-"
                elif 28 <= column <= 30: char = "#"
                elif 31 <= column <= 32: char = "-"
                elif column == 33: char = "#"
                elif column == 34: char = "@"
                elif 35 <= column <= 37: char = "."

            elif row == 3:
                if column == 10: char = "."
                elif column == 11: char = "-"
                elif column == 12: char = "."
                elif column == 13: char = "@"
                elif column == 14: char = "."
                elif column == 15: char = "#"
                elif 16 <= column <= 17: char = "-"
                elif column == 18: char = "."
                elif column == 19: char = "-"
                elif 20 <= column <= 21: char = "#"
                elif column == 22: char = "-"
                elif column == 23: char = "."
                elif 24 <= column <= 29: char = "-"
                elif column == 30: char = "."
                elif 31 <= column <= 32: char = "-"
                elif column == 33: char = "."
                elif column == 34: char = "-"
                elif column == 35: char = "."
                elif column == 36: char = "#"
                elif 37 <= column <= 40: char = "."

            elif row == 4:
                if 8 <= column <= 9: char = "."
                elif column == 10: char = "-"
                elif 11 <= column <= 12: char = "#"
                elif 13 <= column <= 14: char = "-"
                elif column == 15: char = "."
                elif column == 16: char = "-"
                elif column == 17: char = "."
                elif 18 <= column <= 19: char = "#"
                elif 20 <= column <= 21: char = "-"
                elif column == 22: char = "."
                elif 23 <= column <= 27: char = "-"
                elif column == 28: char = "."
                elif 29 <= column <= 32: char = "-"
                elif column == 33: char = "."
                elif column == 34: char = "-"
                elif column == 35: char = "."
                elif column == 36: char = "-"
                elif column == 38: char = "#"
                elif 39 <= column <= 41: char = "."

            elif row == 5:
                if 8 <= column <= 9: char = "-"
                elif column == 10: char = "."
                elif column == 11: char = "-"
                elif column == 12: char = "."
                elif column == 13: char = "-"
                elif 14 <= column <= 15: char = "#"
                elif 16 <= column <= 17: char = "-"
                elif column == 18: char = "."
                elif 19 <= column <= 22: char = "-"
                elif column == 23: char = "."
                elif 24 <= column <= 25: char = "-"
                elif column == 26: char = "."
                elif 27 <= column <= 30: char = "-"
                elif column == 31: char = "."
                elif 32 <= column <= 33: char = "-"
                elif column == 34: char = "."
                elif column == 35: char = "-"
                elif 36 <= column <= 37: char = "#"
                elif column == 38: char = "."
                elif column == 39: char = "#"
                elif 40 <= column <= 41: char = "-"
                elif 42 <= column <= 42: char = "."

            elif row == 6:
                if 7 <= column <= 8: char = "#"
                elif column == 9: char = "."
                elif column == 10: char = "#"
                elif 11 <= column <= 12: char = "-"
                elif 13 <= column <= 14: char = "#"
                elif 15 <= column <= 16: char = "-"
                elif column == 17: char = "."
                elif 18 <= column <= 19: char = "-"
                elif column == 20: char = "."
                elif column == 21: char = "-"
                elif column == 22: char = "."
                elif column == 23: char = "-"
                elif column == 24: char = "."
                elif 25 <= column <= 26: char = "-"
                elif column == 27: char = "."
                elif column == 28: char = "-"
                elif column == 29: char = "."
                elif 30 <= column <= 31: char = "-"
                elif column == 32: char = "."
                elif column == 33: char = "-"
                elif 34 <= column <= 35: char = "#"
                elif column == 36: char = "."
                elif column == 37: char = "#"
                elif 38 <= column <= 43: char = "."

            elif row == 7:
                if 6 <= column <= 7: char = "-"
                elif column == 8: char = "."
                elif column == 9: char = "-"
                elif column == 10: char = "."
                elif 11 <= column <= 12: char = "-"
                elif column == 13: char = "#"
                elif 14 <= column <= 17: char = "-"
                elif column == 18: char = "."
                elif 19 <= column <= 20: char = "-"
                elif column == 21: char = "."
                elif column == 22: char = "-"
                elif column == 23: char = "."
                elif column == 24: char = "-"
                elif column == 25: char = "."
                elif 26 <= column <= 27: char = "-"
                elif column == 28: char = "."
                elif column == 29: char = "-"
                elif column == 30: char = "."
                elif 31 <= column <= 32: char = "-"
                elif column == 33: char = "."
                elif column == 34: char = "-"
                elif 35 <= column <= 36: char = "#"
                elif column == 37: char = "-"
                elif 38 <= column <= 39: char = "#"
                elif 40 <= column <= 41: char = "-"
                elif 42 <= column <= 43: char = "."

            elif row == 8:
                if column == 6: char = "#"
                elif column == 7: char = "."
                elif column == 8: char = "-"
                elif column == 9: char = "."
                elif column == 10: char = "-"
                elif column == 11: char = "#"
                elif 12 <= column <= 16: char = "-"
                elif column == 17: char = "."
                elif 18 <= column <= 22: char = "-"
                elif column == 23: char = "."
                elif column == 24: char = "-"
                elif column == 25: char = "."
                elif column == 26: char = "#"
                elif column == 27: char = "."
                elif column == 28: char = "-"
                elif column == 29: char = "."
                elif column == 30: char = "-"
                elif 31 <= column <= 35: char = "."
                elif column == 36: char = "-"
                elif column == 37: char = "."
                elif column == 38: char = "-"
                elif 39 <= column <= 40: char = "#"
                elif column == 41: char = "-"
                elif 42 <= column <= 43: char = "."

            elif row == 9:
                if column == 6: char = "."
                elif column == 7: char = "-"
                elif column == 8: char = "#"
                elif 9 <= column <= 12: char = "-"
                elif column == 13: char = "."
                elif column == 14: char = "-"
                elif column == 15: char = "."
                elif 16 <= column <= 19: char = "-"
                elif 20 <= column <= 21: char = "#"
                elif 22 <= column <= 23: char = "-"
                elif 24 <= column <= 27: char = "@"
                elif column == 28: char = "#"
                elif column == 29: char = "@"
                elif 30 <= column <= 31: char = "#"
                elif column == 32: char = "-"
                elif column == 33: char = "#"
                elif 34 <= column <= 37: char = "@"
                elif column == 38: char = "#"
                elif column == 39: char = "-"
                elif column == 40: char = "#"
                elif 41 <= column <= 42: char = "-"
                elif column == 43: char = "#"

            elif row == 10:
                if column == 7: char = "#"
                elif column == 8: char = "."
                elif 9 <= column <= 10: char = "-"
                elif column == 11: char = "#"
                elif column == 12: char = "-"
                elif column == 13: char = "."
                elif column == 14: char = "#"
                elif 15 <= column <= 16: char = "-"
                elif column == 17: char = "."
                elif 18 <= column <= 19: char = "-"
                elif column == 20: char = "."
                elif 21 <= column <= 23: char = "#"
                elif column == 24: char = "@"
                elif 25 <= column <= 27: char = "#"
                elif column == 28: char = "@"
                elif column == 29: char = "."
                elif column == 30: char = "-"
                elif column == 31: char = "@"
                elif 32 <= column <= 33: char = "-"
                elif 34 <= column <= 37: char = "@"
                elif column == 38: char = "-"
                elif 39 <= column <= 40: char = "#"
                elif column == 41: char = "-"
                elif column == 42: char = "#"
                elif column == 43: char = "."

            elif row == 11:
                if column == 7: char = "-"
                elif 8 <= column <= 9: char = "#"
                elif column == 10: char = "-"
                elif 11 <= column <= 12: char = "#"
                elif 13 <= column <= 14: char = "-"
                elif column == 15: char = "."
                elif column == 16: char = "-"
                elif column == 17: char = "."
                elif 18 <= column <= 19: char = "#"
                elif column == 20: char = "."
                elif column == 24: char = "-"
                elif 25 <= column <= 26: char = "#"
                elif column == 27: char = "-"
                elif 28 <= column <= 29: char = "#"
                elif column == 30: char = "."
                elif column == 31: char = "-"
                elif 32 <= column <= 33: char = "#"
                elif column == 34: char = "."
                elif column == 36: char = "."
                elif 37 <= column <= 38: char = "-"
                elif 39 <= column <= 41: char = "#"
                elif column == 43: char = "#"

            elif row == 12:
                if 8 <= column <= 9: char = "#"
                elif 10 <= column <= 11: char = "."
                elif 12 <= column <= 13: char = "-"
                elif column == 14: char = "."
                elif 15 <= column <= 16: char = "-"
                elif 17 <= column <= 18: char = "."
                elif 19 <= column <= 21: char = "-"
                elif column == 22: char = "."
                elif 23 <= column <= 24: char = "-"
                elif column == 25: char = "."
                elif 26 <= column <= 27: char = "-"
                elif column == 28: char = "."
                elif column == 29: char = "-"
                elif column == 30: char = "."
                elif 31 <= column <= 32: char = "#"
                elif 33 <= column <= 34: char = "-"
                elif column == 35: char = "."
                elif column == 36: char = "-"
                elif 37 <= column <= 38: char = "#"
                elif column == 39: char = "."
                elif column == 40: char = "-"
                elif 41 <= column <= 42: char = "."

            elif row == 13:
                if column == 8: char = "-"
                elif column == 9: char = "."
                elif column == 10: char = "-"
                elif 11 <= column <= 12: char = "#"
                elif column == 13: char = "."
                elif 14 <= column <= 15: char = "-"
                elif column == 16: char = "."
                elif column == 17: char = "-"
                elif column == 18: char = "."
                elif 19 <= column <= 20: char = "-"
                elif column == 21: char = "."
                elif 22 <= column <= 23: char = "-"
                elif column == 24: char = "#"
                elif 25 <= column <= 26: char = "-"
                elif column == 27: char = "."
                elif column == 28: char = "-"
                elif column == 29: char = "."
                elif column == 30: char = "-"
                elif column == 31: char = "."
                elif column == 32: char = "-"
                elif 33 <= column <= 34: char = "#"
                elif column == 35: char = "."
                elif column == 36: char = "-"
                elif 37 <= column <= 38: char = "#"
                elif column == 39: char = "-"
                elif 40 <= column <= 41: char = "."

            elif row == 14:
                if column == 8: char = "."
                elif column == 9: char = "#"
                elif column == 10: char = "."
                elif column == 11: char = "-"
                elif 12 <= column <= 13: char = "#"
                elif 14 <= column <= 18: char = "-"
                elif column == 19: char = "."
                elif 20 <= column <= 21: char = "-"
                elif column == 22: char = "."
                elif 23 <= column <= 24: char = "#"
                elif column == 25: char = "@"
                elif column == 26: char = "#"
                elif 27 <= column <= 30: char = "."
                elif 31 <= column <= 32: char = "#"
                elif column == 33: char = "@"
                elif column == 34: char = "."
                elif column == 35: char = "-"
                elif 36 <= column <= 37: char = "#"
                elif 38 <= column <= 39: char = "-"
                elif 40 <= column <= 41: char = "#"
                elif column == 42: char = "@"

            elif row == 15:
                if 8 <= column <= 9: char = "-"
                elif column == 10: char = "."
                elif column == 11: char = "-"
                elif 12 <= column <= 13: char = "#"
                elif column == 14: char = "-"
                elif column == 15: char = "."
                elif 16 <= column <= 19: char = "-"
                elif column == 20: char = "."
                elif column == 21: char = "#"
                elif column == 22: char = "."
                elif column == 23: char = "-"
                elif 24 <= column <= 25: char = "."
                elif 26 <= column <= 27: char = "-"
                elif 28 <= column <= 31: char = "@"
                elif column == 32: char = "#"
                elif 33 <= column <= 34: char = "-"
                elif 35 <= column <= 36: char = "#"
                elif column == 37: char = "."
                elif column == 38: char = "-"
                elif 39 <= column <= 40: char = "#"
                elif column == 41: char = "@"
                elif column == 42: char = "-"
                elif column == 43: char = "@"

            elif row == 16:
                if column == 12: char = "@"
                elif 13 <= column <= 14: char = "-"
                elif 15 <= column <= 17: char = "#"
                elif 18 <= column <= 19: char = "-"
                elif column == 20: char = "#"
                elif column == 21: char = "."
                elif column == 22: char = "-"
                elif column == 23: char = "."
                elif column == 25: char = "."
                elif column == 26: char = "-"
                elif column == 27: char = "."
                elif column == 28: char = "-"
                elif column == 29: char = "."
                elif column == 30: char = "-"
                elif 31 <= column <= 32: char = "#"
                elif 33 <= column <= 34: char = "-"
                elif 35 <= column <= 36: char = "#"
                elif column == 37: char = "-"
                elif column == 38: char = "#"
                elif column == 39: char = "@"
                elif column == 40: char = "#"

            elif row == 17:
                if column == 12: char = "."
                elif column == 13: char = "@"
                elif 14 <= column <= 19: char = "-"
                elif column == 20: char = "."
                elif column == 21: char = "-"
                elif column == 22: char = "."
                elif 23 <= column <= 26: char = "@"
                elif column == 27: char = "-"
                elif column == 28: char = "."
                elif column == 29: char = "-"
                elif 30 <= column <= 32: char = "#"
                elif 33 <= column <= 34: char = "@"
                elif 35 <= column <= 36: char = "#"
                elif column == 37: char = "-"
                elif column == 38: char = "#"
                elif column == 39: char = "-"
                elif column == 40: char = "#"
                elif column == 41: char = "."

            elif row == 18:
                if column == 11: char = "-"
                elif 13 <= column <= 14: char = "#"
                elif 15 <= column <= 16: char = "-"
                elif 17 <= column <= 18: char = "#"
                elif 19 <= column <= 20: char = "-"
                elif column == 21: char = "."
                elif column == 22: char = "-"
                elif column == 23: char = "."
                elif column == 24: char = "-"
                elif column == 25: char = "."
                elif 28 <= column <= 31: char = "."
                elif 32 <= column <= 33: char = "-"
                elif column == 34: char = "."
                elif column == 35: char = "-"
                elif 36 <= column <= 37: char = "@"
                elif 38 <= column <= 39: char = "#"
                elif column == 40: char = "."

            elif row == 19:
                if column == 12: char = "."
                elif column == 13: char = "#"
                elif 14 <= column <= 15: char = "-"
                elif column == 16: char = "#"
                elif 17 <= column <= 18: char = "-"
                elif column == 19: char = "."
                elif column == 20: char = "-"
                elif column == 21: char = "#"
                elif column == 22: char = "-"
                elif column == 23: char = "."
                elif column == 24: char = "-"
                elif 25 <= column <= 26: char = "-"
                elif column == 27: char = "."
                elif column == 28: char = "-"
                elif 29 <= column <= 30: char = "#"
                elif 31 <= column <= 32: char = "-"
                elif column == 33: char = "#"
                elif column == 34: char = "-"
                elif column == 35: char = "."
                elif 36 <= column <= 37: char = "-"
                elif 38 <= column <= 39: char = "#"

            elif row == 20:
                if column == 13: char = "@"
                elif column == 14: char = "#"
                elif column == 15: char = "-"
                elif column == 16: char = "@"
                elif 17 <= column <= 18: char = "#"
                elif column == 19: char = "-"
                elif column == 20: char = "#"
                elif 21 <= column <= 22: char = "."
                elif column == 23: char = "-"
                elif column == 24: char = "."
                elif column == 25: char = "-"
                elif column == 26: char = "."
                elif 27 <= column <= 28: char = "-"
                elif 29 <= column <= 30: char = "#"
                elif 31 <= column <= 32: char = "-"
                elif column == 33: char = "."
                elif column == 34: char = "-"
                elif column == 35: char = "."
                elif column == 37: char = "@"
                elif column == 38: char = "#"

            elif row == 21:
                if column == 11: char = "."
                elif column == 12: char = "#"
                elif column == 13: char = "-"
                elif 14 <= column <= 15: char = "#"
                elif column == 16: char = "-"
                elif 17 <= column <= 18: char = "#"
                elif column == 19: char = "@"
                elif column == 20: char = "#"
                elif 21 <= column <= 23: char = "-"
                elif column == 24: char = "."
                elif column == 25: char = "-"
                elif 26 <= column <= 28: char = "#"
                elif column == 29: char = "-"
                elif 30 <= column <= 31: char = "#"
                elif 32 <= column <= 33: char = "-"
                elif column == 34: char = "."
                elif column == 35: char = "#"
                elif column == 36: char = "@"
                elif column == 37: char = "#"

            elif row == 22:
                if column == 9: char = "#"
                elif column == 11: char = "."
                elif 13 <= column <= 14: char = "#"
                elif 15 <= column <= 16: char = "-"
                elif 17 <= column <= 18: char = "#"
                elif column == 19: char = "@"
                elif column == 20: char = "#"
                elif column == 21: char = "-"
                elif column == 22: char = "@"
                elif 23 <= column <= 24: char = "#"
                elif column == 25: char = "-"
                elif column == 26: char = "."
                elif column == 29: char = "."
                elif column == 30: char = "-"
                elif column == 31: char = "."
                elif 33 <= column <= 34: char = "#"
                elif column == 35: char = "@"
                elif 36 <= column <= 37: char = "#"

            elif row == 23:
                if column == 6: char = "."
                elif 7 <= column <= 9: char = "@"
                elif 11 <= column <= 12: char = "."
                elif column == 14: char = "."
                elif column == 15: char = "@"
                elif 16 <= column <= 17: char = "-"
                elif 18 <= column <= 19: char = "#"
                elif column == 20: char = "."
                elif column == 21: char = "-"
                elif 22 <= column <= 23: char = "#"
                elif 24 <= column <= 25: char = "-"
                elif 26 <= column <= 27: char = "#"
                elif 28 <= column <= 30: char = "-"
                elif 31 <= column <= 32: char = "#"
                elif 33 <= column <= 34: char = "-"
                elif 35 <= column <= 36: char = "#"
                elif column == 38: char = "."

            elif row == 24:
                if column == 4: char = "."
                elif 5 <= column <= 6: char = "@"
                elif column == 7: char = "#"
                elif 8 <= column <= 10: char = "@"
                elif 12 <= column <= 15: char = "."
                elif column == 17: char = "."
                elif column == 18: char = "@"
                elif column == 19: char = "#"
                elif 20 <= column <= 23: char = "-"
                elif column == 24: char = "."
                elif 25 <= column <= 26: char = "-"
                elif 27 <= column <= 28: char = "#"
                elif column == 29: char = "-"
                elif 30 <= column <= 32: char = "#"
                elif 33 <= column <= 36: char = "@"
                elif column == 37: char = "."

            elif row == 25:
                if column == 0: char = "."
                elif column == 1: char = "#"
                elif 2 <= column <= 8: char = "@"
                elif column == 9: char = "#"
                elif column == 10: char = "@"
                elif 12 <= column <= 18: char = "."
                elif column == 20: char = "-"
                elif column == 21: char = "@"
                elif 22 <= column <= 23: char = "-"
                elif 24 <= column <= 25: char = "#"
                elif 26 <= column <= 27: char = "-"
                elif 28 <= column <= 29: char = "#"
                elif column == 30: char = "@"
                elif column == 31: char = "#"
                elif column == 32: char = "@"
                elif 34 <= column <= 35: char = "."
                elif 36 <= column <= 41: char = "@"

            elif row == 26:
                if 0 <= column <= 1: char = "#"
                elif 2 <= column <= 5: char = "@"
                elif 6 <= column <= 7: char = "#"
                elif 8 <= column <= 11: char = "@"
                elif 13 <= column <= 20: char = "."
                elif column == 22: char = "."
                elif column == 23: char = "@"
                elif 24 <= column <= 25: char = "-"
                elif 26 <= column <= 27: char = "#"
                elif column == 28: char = "-"
                elif 29 <= column <= 30: char = "#"
                elif column == 31: char = "@"
                elif 34 <= column <= 37: char = "."
                elif 38 <= column <= 45: char = "@"
                elif column == 46: char = "."

            elif row == 27:
                if column == 0: char = "#"
                elif 1 <= column <= 2: char = "@"
                elif column == 3: char = "#"
                elif 4 <= column <= 5: char = "@"
                elif 6 <= column <= 7: char = "#"
                elif 8 <= column <= 9: char = "@"
                elif column == 10: char = "#"
                elif column == 11: char = "@"
                elif 13 <= column <= 22: char = "."
                elif 25 <= column <= 26: char = "#"
                elif 27 <= column <= 28: char = "@"
                elif 31 <= column <= 36: char = "."
                elif 37 <= column <= 47: char = "@"

            elif row == 28:
                if column == 0: char = "#"
                elif 1 <= column <= 2: char = "@"
                elif column == 3: char = "#"
                elif column == 4: char = "@"
                elif column == 5: char = "#"
                elif 6 <= column <= 7: char = "@"
                elif column == 8: char = "#"
                elif 9 <= column <= 10: char = "@"
                elif column == 11: char = "#"
                elif column == 12: char = "@"
                elif 14 <= column <= 21: char = "."
                elif column == 23: char = "."
                elif 24 <= column <= 29: char = "@"
                elif 32 <= column <= 37: char = "."
                elif 38 <= column <= 48: char = "@"


            elif row == 29:
                if column == 0: char = "#"
                elif 1 <= column <= 2: char = "@"
                elif column == 3: char = "#"
                elif 4 <= column <= 5: char = "@"
                elif 6 <= column <= 7: char = "#"
                elif 8 <= column <= 9: char = "@"
                elif column == 10: char = "#"
                elif column == 11: char = "@"
                elif 13 <= column <= 22: char = "."
                elif 25 <= column <= 26: char = "#"
                elif 27 <= column <= 28: char = "@"
                elif 31 <= column <= 36: char = "."
                elif 37 <= column <= 47: char = "@"
            line = line + char
        print(line)
JamesCameron_ascii_art()
# Out:
#                  .#----##-###-.-..
#               .-.-.-.-.#@#.-##-#-.-.
#             --.-.-.--#. .#--###--#@...
#           .-.@.#--.-##-.------.--.-.#....
#         ..-##--.-.##--.-----.----.-.- #...
#         --.-.-##--.----.--.----.--.-##.#--.
#        ##.#--##--.--.-.-.--.-.--.-##.#......
#       --.-.--#----.--.-.-.--.-.--.-##-##--..
#       #.-.-#-----.-----.-.#.-.-.....-.-##-..
#       .-#----.-.----##--@@@@#@##-#@@@@#-#--#
#        #.--#-.#--.--.###@###@.-@--@@@@-##-#.
#        -##-##--.-.##.   -##-##.-##. .--### #
#         ##..--.--..---.--.--.-.##--.-##.-..
#         -.-##.--.-.--.--#--.-.-.-##.-##-..
#         .#.-##-----.--.##@#....##@.-##--##@
#         --.-##-.----.#.-..--@@@@#--##.-##@-@
#             @--###--#.-. .-.-.-##--##-#@#
#             .@------.-.@@@@-.-###@@##-#-#.
#            - ##--##--.-.-.  ....--.-@@##.
#             .#--#--.-#-.---.-##--#-.--##
#              @#-@##-#..-.-.--##--.-. @#
#            .#-##-##@#---.-###-##--.#@#
# ...
